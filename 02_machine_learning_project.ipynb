# %% [markdown]
# <a href="https://colab.research.google.com/github/ArkaanHilmiS/RuangGuru_AI/blob/main/02_machine_learning_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Proyek Machine Learning: Lembar Pengumpulan Jawaban
#
# **Petunjuk Penting:**
# 1. Notebook ini HANYA digunakan untuk mengumpulkan jawaban.
# 2. Semua jawaban dapat ditemukan dengan menggunakan **Simulasi Interaktif** yang tautannya diberikan di setiap tugas.
# 3. Buka simulasi, ikuti petunjuknya, dapatkan nilai yang diminta, lalu masukkan jawaban Anda ke dalam variabel yang sesuai di notebook ini.
# 4. Setelah mengisi jawaban untuk satu tugas, Anda bisa langsung menjalankan sel **Submit Jawaban** di bawahnya.

# %% [markdown]
# ## Identitas Siswa & Pengaturan Grader

# %%
# @title #### Masukkan Identitas Anda
student_id = "REAENG11UVKIF" # @param {type:"string"}
name = "Arkaan Hilmi Suharsoyo" # @param {type:"string"}

# drive_link diisi dengan link folder drive anda
# yang berisi notebook/project-project anda kedepannya
drive_link = "https://drive.google.com/drive/folders/1Y4BqGyI2F1MyQlHKY5T9rNqa40F--bW-?usp=sharing"  # @param {type:"string"}
batch = "batch-11"# @param {type:"string"}

# ID Tugas (Jangan diubah)
assignment_id = "01_ml_submission_project"

# Instalasi dan impor grader (Jangan diubah)
# %pip install rggrader2
from rggrader import submit

# %% [markdown]
# ---

# %% [markdown]
# ## Tugas 1 & 2: Supervised vs. Unsupervised Learning
#
# Buka simulasi pada tautan di bawah ini untuk menemukan jawaban dari kedua pertanyaan berikut.
#
# **Tautan Simulasi:** https://ruang-guru.github.io/ai-bootcamp-interactive/docs/machine-learning-fundamental/02-supervised-vs-unsupervised.html

# %%
# --- MASUKKAN JAWABAN ANDA DI SINI ---

# Soal 1: (Supervised) Berapa prediksi tinggi badan untuk seseorang dengan berat 88 kg?
prediksi_tinggi_badan = 206.0

# Soal 2: (Unsupervised) Data point dengan fitur (X=3, Y=5) masuk ke dalam cluster nomor berapa?
prediksi_cluster = 3

# %% [markdown]
# ### Submit Jawaban Tugas 1 & 2

# %%
# Jalankan sel ini untuk mengirim jawaban Tugas 1 dan 2
print("Status Soal 1: ", submit(student_id, name, assignment_id, str(prediksi_tinggi_badan), batch, "01_supervised_height_prediction",  drive_link))
print("Status Soal 2: ", submit(student_id, name, assignment_id, str(prediksi_cluster), batch, "02_unsupervised_cluster_prediction",  drive_link))
# Out:
# Status Soal 1:  Assignment successfully submitted. Score: 100
# Status Soal 2:  Assignment successfully submitted. Score: 100

# %% [markdown]
# ---

# %% [markdown]
# ## Tugas 3: Analisis Overfitting
#
# Buka simulasi pada tautan di bawah ini. Atur nilai input pada simulasi sesuai instruksi untuk mendapatkan jawaban.
#
# **Tautan Simulasi:** https://ruang-guru.github.io/ai-bootcamp-interactive/docs/machine-learning-fundamental/03-overfitting.html
#
# **Pengaturan pada Simulasi:**
# - Pada bagian pengaturan data, masukkan nilai **Seed** sebesar **38**.
# - Pada bagian pengaturan model, masukkan **Derajat Polinomial** sebesar **3**.
#
# Cari keempat nilai berikut dari hasil simulasi.

# %%
# --- MASUKKAN JAWABAN ANDA DI SINI ---

# Soal 3.1: Berapa prediksi nilai Y jika nilai X adalah 4?
overfitting_prediksi_y = 334.72

# Soal 3.2: Berapa nilai Training Score?
overfitting_training_score = 0.886

# Soal 3.3: Berapa nilai Validation Score?
overfitting_validation_score = 0.832

# Soal 3.4: Berapa nilai Overfitting Index (selisih Training dan Validation Score)?
overfitting_index = 0.054

# %% [markdown]
# ### Submit Jawaban Tugas 3

# %%
# Jalankan sel ini untuk mengirim jawaban Tugas 3
print("Status soal 3.1.:", submit(student_id, name, assignment_id, str(overfitting_prediksi_y), batch, "03_overfitting_y_prediction_v2", drive_link))
print("Status soal 3.2.:", submit(student_id, name, assignment_id, str(overfitting_training_score), batch, "04_overfitting_train_score_v2",  drive_link))
print("Status soal 3.3.:", submit(student_id, name, assignment_id, str(overfitting_validation_score), batch, "05_overfitting_validation_score_v2", drive_link))
print("Status soal 3.4.:", submit(student_id, name, assignment_id, str(overfitting_index), batch, "06_overfitting_index_v2", drive_link))
# Out:
# Status soal 3.1.: Assignment successfully submitted. Score: 100
# Status soal 3.2.: Assignment successfully submitted. Score: 100
# Status soal 3.3.: Assignment successfully submitted. Score: 100
# Status soal 3.4.: Assignment successfully submitted. Score: 100

# %% [markdown]
# ---

# %% [markdown]
# ## Tugas 4: Studi Kasus K-Means Clustering
#
# Buka simulasi studi kasus segmentasi pelanggan pada tautan di bawah ini.
#
# **Tautan Simulasi:** https://ruang-guru.github.io/ai-bootcamp-interactive/docs/machine-learning-fundamental/08-kmeans-case-study.html
#
# **Pertanyaan:** Berapa nilai **rata-rata frekuensi pembelian** untuk cluster di mana pelanggan dengan **pengeluaran tahunan** **5815** berada?

# %%
# --- MASUKKAN JAWABAN ANDA DI SINI ---

kmeans_centroid_frequency = 46

# %% [markdown]
# ### Submit Jawaban Tugas 4

# %%
# Jalankan sel ini untuk mengirim jawaban Tugas 4
print("Status soal 4:", submit(student_id, name, assignment_id, str(kmeans_centroid_frequency), batch, "07_kmeans_centroid_frequency", drive_link))
# Out:
# Status soal 4: Assignment successfully submitted. Score: 100

# %% [markdown]
# ---

# %% [markdown]
# ## Selesai
# Anda telah menyelesaikan semua tugas. Pastikan semua sel submit telah dijalankan dan tidak ada pesan error.
