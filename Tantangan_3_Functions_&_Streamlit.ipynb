# %% [markdown]
# <a href="https://colab.research.google.com/github/ArkaanHilmiS/RuangGuru_AI/blob/main/Tantangan_3_Functions_%26_Streamlit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tantangan
# Yuk kerjakan beberapa tantangan di bawah ini! Sebelum mengerjakan tantangan, jangan lupa masukkan student ID kamu ya!

# %%
# %pip install rggrader2

from rggrader import submit

# @title #### Student Identity
student_id = "REAENG11UVKIF"  # @param {type:"string"}
name = "Arkaan Hilmi Suharsoyo"  # @param {type:"string"}
batch = "batch-11"# @param {type:"string"}
# Out:
# Collecting rggrader2
#   Downloading rggrader2-0.1.2-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from rggrader2) (2.32.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from rggrader2) (11.3.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from rggrader2) (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas->rggrader2) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->rggrader2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->rggrader2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->rggrader2) (2026.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->rggrader2) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->rggrader2) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->rggrader2) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->rggrader2) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->rggrader2) (1.17.0)
# Downloading rggrader2-0.1.2-py3-none-any.whl (3.1 kB)
# Installing collected packages: rggrader2
# Successfully installed rggrader2-0.1.2

# %% [markdown]
# ## Tantangan 1 - Circle Area Function

# %%
# @title #### 00. Circle Area Function
from rggrader import submit
import math

#Variabel yang diberikan untuk kebutuhan submit
rad = 5

# TODO: Define a function 'calculate_area' that takes a radius as a parameter and returns the area of a circle with that radius.
def calculate_circle_area(rad):
  return math.pi * (rad**2)

print(f"The area of the circle with radius {rad} is {calculate_circle_area(rad)}")

# Submit Method
assignment_id = "03_functions-streamlit"
question_id = "01_circle-area-function"
submit(student_id, name, assignment_id, str(calculate_circle_area(rad)), batch, question_id)

# Expected Output for rad=5: 78.53981633974483
# Out:
# The area of the circle with radius 5 is 78.53981633974483
# 'Assignment successfully submitted. Score: 100'

# %% [markdown]
# ## Tantangan 2 - Pengecek Ganjil atau Genap

# %%
# from _typeshed import GenericPath
from rggrader import submit

#Variabel yang diberikan (Tidak untuk diubah ketika submit)
num = 37

# TODO: Buatlah sebuah fungsi bernama 'check_odd_even' yang menerima satu parameter berupa bilangan bulat.
# Fungsi harus mengembalikan string "Genap" jika angka tersebut genap, dan "Ganjil" jika angka tersebut ganjil.

def check_odd_even(num):
  if num % 2 == 0 : return ("Genap")
  else : return ("Ganjil")

print(f"Angka {num} adalah {check_odd_even(num)}")

# Submit Method
assignment_id = "03_functions-streamlit"
question_id = "02_odd-even-checker"
submit(student_id, name, assignment_id, str(check_odd_even(num)), batch, question_id)

# Expected Output jika num = 37:
# Angka 37 adalah Ganjil
# Out:
# Angka 37 adalah Ganjil
# 'Assignment successfully submitted. Score: 100'

# %% [markdown]
# # Tantangan 3 - Menebak Komponen Streamlit

# %%
from rggrader import submit

# Deskripsi soal:
# Streamlit memiliki berbagai komponen interaktif seperti text input, tombol, dan dropdown.
# Pilih komponen yang paling sesuai dengan deskripsi di bawah ini.

# Soal:
# 1. Komponen apa yang digunakan untuk meminta pengguna memasukkan teks?
# 2. Komponen apa yang digunakan untuk membuat tombol yang bisa ditekan oleh pengguna?
# 3. Komponen apa yang digunakan untuk membuat dropdown list pilihan?

# TODO: Buatlah fungsi `streamlit_component` yang menerima nomor soal sebagai input dan
# mengembalikan nama komponen Streamlit yang sesuai (misalnya "st.text_input", "st.button", dll).
# Lengkapi kode fungsi ini agar dapat memberikan jawaban yang benar.

def streamlit_component(question_number):
    if question_number == 1:
        return "st.text_input"
    elif question_number == 2:
        return "st.button"
    elif question_number == 3:
        return "st.selectbox"
    else:
        return None

# Outputkan hasil untuk setiap soal
print(f"Soal 1: {streamlit_component(1)}")
print(f"Soal 2: {streamlit_component(2)}")
print(f"Soal 3: {streamlit_component(3)}")

# Submit Method
assignment_id = "03_functions-streamlit"
question_id = "03-streamlit-component"
submit(student_id, name, assignment_id, str(streamlit_component(1)), batch, question_id)
# Out:
# Soal 1: st.text_input
# Soal 2: st.button
# Soal 3: st.selectbox
# 'Assignment successfully submitted. Score: 100'
