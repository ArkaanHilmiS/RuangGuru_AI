# %% [markdown]
# <a href="https://colab.research.google.com/github/ArkaanHilmiS/RuangGuru_AI/blob/main/Tantangan_2_Looping_%26_Collections.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tantangan
# Yuk kerjakan beberapa tantangan di bawah ini! Sebelum mengerjakan tantangan, jangan lupa masukkan student ID kamu ya!

# %%
# %pip install rggrader2

from rggrader import submit

# @title #### Student Identity
student_id = "REAENG11UVKIF"  # @param {type:"string"}
name = "Arkaan Hilmi Suharsoyo"  # @param {type:"string"}
batch = "batch-11"# @param {type:"string"}
# Out:
# Collecting rggrader2
#   Downloading rggrader2-0.1.2-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from rggrader2) (2.32.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from rggrader2) (11.3.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from rggrader2) (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas->rggrader2) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->rggrader2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->rggrader2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->rggrader2) (2026.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->rggrader2) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->rggrader2) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->rggrader2) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->rggrader2) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->rggrader2) (1.17.0)
# Downloading rggrader2-0.1.2-py3-none-any.whl (3.1 kB)
# Installing collected packages: rggrader2
# Successfully installed rggrader2-0.1.2

# %% [markdown]
# ## Tantangan 1 - Fun with Fruits

# %%
# @title #### 01. Fun with Fruits
from rggrader import submit

# TODO: Create a list 'fruits' that contains "Apple", "Banana", and "Cherry".
# Then remove "Banana" from the 'fruits' list and append "Dragonfruit" and "Elderberry".
fruits = ["Apple", "Banana", "Cherry"]
fruits.remove("Banana")
fruits.append("Dragonfruit")
fruits.append("Elderberry")

# Put your code here:


# ---- End of your code ----

print(f"The final fruits list is {fruits}")

# Submit Method
assignment_id = "02_looping-collections"
question_id = "01_fun_with_fruits"
submit(student_id, name, assignment_id, ", ".join(fruits), batch, question_id)
# Out:
# The final fruits list is ['Apple', 'Cherry', 'Dragonfruit', 'Elderberry']
# 'Assignment successfully submitted. Score: 100'

# %% [markdown]
# ## Tantangan 2 - Trip to Bussels

# %%
# @title #### 02. Trip to Brussels
from rggrader import submit

# TODO: You're planning a trip to Brussels!
#       1. Start with a list 'places_to_visit' containing: ["Grand Place", "Royal Palace", "Atomium"]
#       2. Then remove "Royal Palace" and add both "Manneken Pis" and "Mini Europe" to the list
#       3. Create a dictionary 'brussels_info' with the following initial information:
#          - 'country': 'Belgium'
#          - 'language': 'French'
#       4. Update the 'language' value to 'French and Dutch'
#       5. Add a new key 'population' with value 1200000


# Put your code here:
places_to_visit = ["Grand Place", "Royal Palace", "Atomium"]
places_to_visit.remove("Royal Palace")
places_to_visit.append("Manneken Pis")
places_to_visit.append("Mini Europe")
brussels_info = {"country": "Belgium", "language": "French"}
brussels_info["language"] = "French and Dutch"
brussels_info["population"] = 1200000


# ---- End of your code ----

print(f"Places to visit in Brussels: {places_to_visit}")
print(f"Information about Brussels: {brussels_info}")

# Submit Method
assignment_id = "02_looping-collections"
question_id = "02_trip_to_brussels"
submit(student_id, name, assignment_id, str(places_to_visit) + " | " + str(brussels_info), batch, question_id)

# Expected Output:
# Places to visit in Brussels: ['Grand Place', 'Atomium', 'Manneken Pis', 'Mini Europe']
# Information about Brussels: {'country': 'Belgium', 'language': 'French and Dutch', 'population': 1200000}
# Out:
# Places to visit in Brussels: ['Grand Place', 'Atomium', 'Manneken Pis', 'Mini Europe']
# Information about Brussels: {'country': 'Belgium', 'language': 'French and Dutch', 'population': 1200000}
# 'Assignment successfully submitted. Score: 100'

# %% [markdown]
# ## Tantangan 3 - Birthday Party

# %%
# @title #### 03. Birthday Party
from rggrader import submit

# TODO: You're throwing a birthday party! Create a dictionary 'ages' that contains key-value pairs of your friends' names
#       and their ages: "Alice": 25, "Bob": 30, "Charlie": 35.
# Alice just had her birthday! So, change the age of "Alice" to 26. Then, add your friend "David" who is 40 to the party.


# Put your code here:
ages = {"Alice": 25, "Bob": 30, "Charlie": 35}
ages["Alice"] = 26
ages["David"] = 40


# ---- End of your code ----

print(f"The final ages dictionary is {ages}")

# Submit Method
assignment_id = "02_looping-collections"
question_id = "03_birthday_party"
submit(student_id, name, assignment_id, str(ages), batch, question_id)

# Example (Not Expected Output):
# Dictionary: {"John": 28, "Linda": 25, "Peter": 30}
# Change Age: John turns 29
# Add New Friend: {"Mary": 32}
# Output: {"John": 29, "Linda": 25, "Peter": 30, "Mary": 32}
# Out:
# The final ages dictionary is {'Alice': 26, 'Bob': 30, 'Charlie': 35, 'David': 40}
# 'Assignment successfully submitted. Score: 100'
