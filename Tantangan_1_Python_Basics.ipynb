# %% [markdown]
# <a href="https://colab.research.google.com/github/ArkaanHilmiS/RuangGuru_AI/blob/main/Tantangan_1_Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tantangan
# Yuk kerjakan beberapa tantangan di bawah ini! Sebelum mengerjakan tantangan, jangan lupa masukkan student ID kamu ya!

# %%
# %pip install rggrader2

from rggrader import submit

# @title #### Student Identity
student_id = "REAENG11UVKIF"  # @param {type:"string"}
name = "Arkaan Hilmi Suharsoyo"  # @param {type:"string"}
batch = "batch-11"# @param {type:"string"}
# Out:
# Collecting rggrader2
#   Downloading rggrader2-0.1.2-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from rggrader2) (2.32.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from rggrader2) (11.3.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from rggrader2) (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas->rggrader2) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->rggrader2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->rggrader2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->rggrader2) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->rggrader2) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->rggrader2) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->rggrader2) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->rggrader2) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->rggrader2) (1.17.0)
# Downloading rggrader2-0.1.2-py3-none-any.whl (3.1 kB)
# Installing collected packages: rggrader2
# Successfully installed rggrader2-0.1.2

# %% [markdown]
# ## Tantangan 1: Generator Biodata
#
# Buatlah program yang menghasilkan biodata lengkap menggunakan f-string dari variabel-variabel yang diberikan.
# Format output harus sesuai dengan contoh berikut:
#
# Contoh output yang diharapkan:
# ```
# BIODATA LENGKAP
# Nama    : John Doe
# Usia    : 25 tahun
# Tinggi  : 170.5 cm
# Status  : Aktif
# ```

# %%
# @title #### 01. Generator Biodata
from rggrader import submit

# Variabel yang diberikan - TIDAK UNTUK DIUBAH
nama = "John Doe"
usia = 25
tinggi = 170.5
status = "Aktif"

# TODO:
# Buat biodata terformat menggunakan f-string
# Format output harus sesuai dengan contoh
# Simpan hasilnya dalam variabel 'biodata'

# Output setelah di-print akan terlihat seperti ini:
# BIODATA LENGKAP
# Nama    : John Doe
# Usia    : 25 tahun
# Tinggi  : 170.5 cm
# Status  : Aktif

# Tulis kode kamu di sini:
biodata = f"""BIODATA LENGKAP
Nama    : {nama}
Usia    : {usia} tahun
Tinggi  : {tinggi} cm
Status  : {status}"""

print (biodata)

# ---- Akhir dari kode kamu ----

# Submit Method
assignment_id = "01_python-basics"
question_id = "01_biodata-generator"
submit(student_id, name, assignment_id, biodata, batch, question_id)
# Out:
# BIODATA LENGKAP
# Nama    : John Doe
# Usia    : 25 tahun
# Tinggi  : 170.5 cm
# Status  : Aktif
# 'Assignment successfully submitted. Score: 100'

# %% [markdown]
# ## Tantangan 2: Kalkulator String
#
# Buatlah program yang mengubah operasi penjumlahan menjadi kalimat yang menjelaskan operasi tersebut.
#
# Contoh:
# - Input: num1 = 10, num2 = 5
# - Output yang diharapkan: "Hasil dari 10 tambah 5 adalah 15"

# %%
# @title #### 02. Kalkulator String
from rggrader import submit

# Variabel yang diberikan
num1 = 10
num2 = 5

# TODO:
# Buat kalimat yang menjelaskan operasi penjumlahan
# Gunakan f-string untuk membuat kalimat yang menjelaskan operasi penjumlahan
# dari num1 dan num2, lalu simpan hasilnya dalam variabel 'explanation'
#
# Expected Output:
# explanation = "Hasil dari 10 tambah 5 adalah 15"
#
# Perhatikan:
# - Spasi dan tanda baca harus sama persis!
# - Format kalimat harus sesuai: "Hasil dari {num1} tambah {num2} adalah {hasil}"

# Tulis kode kamu di sini:
explanation = f"Hasil dari {num1} tambah {num2} adalah {num1 + num2}"
print (explanation)

# ---- Akhir dari kode kamu ----

# Submit Method
assignment_id = "01_python-basics"
question_id = "02_string-calculator"
submit(student_id, name, assignment_id, explanation, batch, question_id)
# Out:
# Hasil dari 10 tambah 5 adalah 15
# 'Assignment successfully submitted. Score: 100'
